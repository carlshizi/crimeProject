# %%
import plotly.express as px
import pandas as pd

px.set_mapbox_access_token(open(".mapbox_token").read())
df = pd.read_csv('Daily_Raleigh_Police_Incidents.csv')
df
# Out:
#               X          Y  OBJECTID                              GlobalID  \
# 0    -78.622925  35.874504    529022  c330e7f9-d92e-494e-ac86-5a7668506b52
# 1    -78.622925  35.874504    529023  842c43c3-9411-4d1e-b4d0-c6f8de560892
# 2    -78.634200  35.778107    529035  aa32c9dd-318e-4a7c-906c-3fceec8a0f7e
# 3           NaN        NaN    529038  2ef2112c-3cad-4ddc-a0ed-c9ca3a609288
# 4           NaN        NaN    529046  ac21533f-7ece-4adc-ac07-48a506f27c4f
# ...         ...        ...       ...                                   ...
# 1388 -78.542119  35.947508    611637  56dd389d-0d1c-4132-9f62-cc1a16d0f128
# 1389 -78.701378  35.766386    611638  e9c1a2b6-963c-4e22-8a46-6f62a9dd29c8
# 1390 -78.620680  35.780346    611639  fac94aba-57b0-4caa-a075-b5e9d8c0a9c3
# 1391 -78.620680  35.780346    611640  7bb2095d-f037-48c9-934e-6ea2f340edea
# 1392 -78.620680  35.780346    611641  3c920741-394e-458f-967f-ba18ffe64fac
#
#                     CreationDate     Creator                    EditDate  \
# 0     2020/02/18 20:14:01.341+00  RaleighGIS  2020/02/18 20:14:01.341+00
# 1     2020/02/18 20:14:01.341+00  RaleighGIS  2020/02/18 20:14:01.341+00
# 2     2020/02/18 17:58:16.023+00  RaleighGIS  2020/02/18 17:58:16.023+00
# 3     2020/02/18 17:58:16.023+00  RaleighGIS  2020/02/18 17:58:16.023+00
# 4     2020/02/18 17:58:16.023+00  RaleighGIS  2020/02/18 17:58:16.023+00
# ...                          ...         ...                         ...
# 1388  2021/01/22 05:00:53.045+00  RaleighGIS  2021/01/22 05:00:53.045+00
# 1389  2021/01/22 05:00:53.045+00  RaleighGIS  2021/01/22 05:00:53.045+00
# 1390  2021/01/22 05:00:53.045+00  RaleighGIS  2021/01/22 05:00:53.045+00
# 1391  2021/01/22 05:00:53.045+00  RaleighGIS  2021/01/22 05:00:53.045+00
# 1392  2021/01/22 05:00:53.045+00  RaleighGIS  2021/01/22 05:00:53.045+00
#
#           Editor case_number      crime_category  ...           reported_date  \
# 0     RaleighGIS   P20009234             LARCENY  ...  2020/02/17 05:15:00+00
# 1     RaleighGIS   P20009234               FRAUD  ...  2020/02/17 05:15:00+00
# 2     RaleighGIS   P20009235  ALL OTHER OFFENSES  ...  2020/02/17 05:48:00+00
# 3     RaleighGIS         NaN       MISCELLANEOUS  ...  2020/02/17 06:35:00+00
# 4     RaleighGIS         NaN       MISCELLANEOUS  ...  2020/02/17 08:11:00+00
# ...          ...         ...                 ...  ...                     ...
# 1388  RaleighGIS   P21003310               FRAUD  ...  2021/01/21 16:57:00+00
# 1389  RaleighGIS   P21003312           VANDALISM  ...  2021/01/21 17:09:00+00
# 1390  RaleighGIS   P21003314             ASSAULT  ...  2021/01/21 17:23:00+00
# 1391  RaleighGIS   P21003314     DRUG VIOLATIONS  ...  2021/01/21 17:23:00+00
# 1392  RaleighGIS   P21003314               DRUGS  ...  2021/01/21 17:23:00+00
#
#      reported_year reported_month reported_day reported_hour reported_dayofwk  \
# 0             2020              2           17             0           Monday
# 1             2020              2           17             0           Monday
# 2             2020              2           17             0           Monday
# 3             2020              2           17             1           Monday
# 4             2020              2           17             3           Monday
# ...            ...            ...          ...           ...              ...
# 1388          2021              1           21            11         Thursday
# 1389          2021              1           21            12         Thursday
# 1390          2021              1           21            12         Thursday
# 1391          2021              1           21            12         Thursday
# 1392          2021              1           21            12         Thursday
#
#        latitude  longitude  agency                updated_date
# 0     35.874504 -78.622925     RPD  2020/02/17 22:02:04.983+00
# 1     35.874504 -78.622925     RPD  2020/02/17 22:02:04.983+00
# 2     35.778107 -78.634200     RPD  2020/02/17 16:38:21.820+00
# 3      0.000000   0.000000     RPD  2020/02/17 16:22:49.540+00
# 4      0.000000   0.000000     RPD  2020/02/17 16:39:12.820+00
# ...         ...        ...     ...                         ...
# 1388  35.947508 -78.542119     RPD  2021/01/21 21:34:08.740+00
# 1389  35.766386 -78.701378     RPD  2021/01/21 21:33:59.527+00
# 1390  35.780346 -78.620680     RPD  2021/01/21 23:47:13.757+00
# 1391  35.780346 -78.620680     RPD  2021/01/21 23:47:13.757+00
# 1392  35.780346 -78.620680     RPD  2021/01/21 23:47:13.757+00
#
# [1393 rows x 27 columns]

# %%
# list_in_dist = df['district']
# count = list_in_dist.value_counts(dropna=True)
# listed_count = list(count)
# listed_count

# %%
# list_in_dist = df['district']
# count = list_in_dist.value_counts(dropna=True)
# index_tolist = (count.index).tolist()
# index_tolist

list_in_dist = df['crime_category']
count = list_in_dist.value_counts(dropna=True)
count_tolist = list(count)
index_tolist = (count.index).tolist()

index_tolist = (((df['crime_category']).value_counts(dropna=True)).index).tolist()
index_tolist
# Out:
# ['MISCELLANEOUS',
#  'LARCENY',
#  'VANDALISM',
#  'LARCENY FROM MV',
#  'ASSAULT',
#  'FRAUD',
#  'ALL OTHER OFFENSES',
#  'DRUGS',
#  'WEAPONS VIOLATION',
#  'HUMANE',
#  'BURGLARY/RESIDENTIAL',
#  'MV THEFT',
#  'DRUG VIOLATIONS',
#  'STOLEN PROPERTY',
#  'BURGLARY/COMMERCIAL',
#  'DISORDERLY CONDUCT',
#  'SEX OFFENSES',
#  'TRAFFIC',
#  'ROBBERY',
#  'LIQUOR LAW VIOLATIONS',
#  'OBSCENE MATERIAL',
#  'EXTORTION',
#  'UNAUTHORIZED MOTOR VEHICLE USE',
#  'KIDNAPPING',
#  'PROSTITUTION',
#  'ARSON',
#  'EMBEZZLEMENT']

# %%
df['CreationDate']
# Out:
# 0       2020/02/18 20:14:01.341+00
# 1       2020/02/18 20:14:01.341+00
# 2       2020/02/18 17:58:16.023+00
# 3       2020/02/18 17:58:16.023+00
# 4       2020/02/18 17:58:16.023+00
#                    ...
# 1388    2021/01/22 05:00:53.045+00
# 1389    2021/01/22 05:00:53.045+00
# 1390    2021/01/22 05:00:53.045+00
# 1391    2021/01/22 05:00:53.045+00
# 1392    2021/01/22 05:00:53.045+00
# Name: CreationDate, Length: 1393, dtype: object

# %%
df['CreationDate']
# marks={str(CreationDate): str(CreationDate) for CreationDate in df['CreationDate'].unique()}
# marks
# Out:
# 0       2020/02/18 20:14:01.341+00
# 1       2020/02/18 20:14:01.341+00
# 2       2020/02/18 17:58:16.023+00
# 3       2020/02/18 17:58:16.023+00
# 4       2020/02/18 17:58:16.023+00
#                    ...
# 1388    2021/01/22 05:00:53.045+00
# 1389    2021/01/22 05:00:53.045+00
# 1390    2021/01/22 05:00:53.045+00
# 1391    2021/01/22 05:00:53.045+00
# 1392    2021/01/22 05:00:53.045+00
# Name: CreationDate, Length: 1393, dtype: object

# %%
df['CreationDate'].min()
# Out:
# '2020/02/18 17:58:16.023+00'
